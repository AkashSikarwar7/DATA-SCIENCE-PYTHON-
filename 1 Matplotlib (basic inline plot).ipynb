# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[10,0.09,30,20,50]
z=[1.5,2.3,5.6,8.99,2.4]

# %%
plt.plot(x,y,color='blue',linewidth=1.5,linestyle='dotted')
plt.xlabel('X info')
plt.ylabel('Y info')
plt.title('Information')
# Out:
# Text(0.5, 1.0, 'Information')

# %%
plt.plot(x,z)
