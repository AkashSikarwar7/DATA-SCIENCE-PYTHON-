# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[10,0.09,30,20,50]
z=[10.2,0.6,8.3,9.5,9.1]

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'s')

# %%
plt.plot(x,y,'g*')

# %%
plt.plot(x,y,'r-.')

# %%
plt.plot(x,y,'r-.s')

# %%
plt.plot(x,y,'g-.d')

# %%
plt.plot(x,y,color='red',marker='*',linestyle='')

# %%
plt.plot(x,y,color='#000000',marker='*',linestyle='-.')

# %%
plt.plot(x,y,color='#918899',marker='*',linestyle='dashdot',markersize='20')

# %%
plt.plot(x,y,color='#918899',marker='*',linestyle='dashdot',markersize=20,alpha=0.2)
